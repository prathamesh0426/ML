# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## for 50 startups data extimate the profit

# %% [markdown]
# ## Step 1 - Data ingestion

# %%
import pandas as pd
df = pd.read_csv("50_Startups.csv")
df.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %% [markdown]
# ## Step 2 - Basic data quality
# 1. info - df.info()
# 2. Duplicate - df.drop_duplicated().sum()
# 3. isna = df.isna().sum()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RND     50 non-null     float64
#  1   ADMIN   50 non-null     float64
#  2   MKT     50 non-null     float64
#  3   STATE   50 non-null     object
#  4   PROFIT  50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# RND       0
# ADMIN     0
# MKT       0
# STATE     0
# PROFIT    0
# dtype: int64

# %%
import seaborn as sns
sns.pairplot(data = df, kind = "reg")

# %%
df.corr(numeric_only=True)
# Out:
#              RND     ADMIN       MKT    PROFIT
# RND     1.000000  0.241955  0.724248  0.972900
# ADMIN   0.241955  1.000000 -0.032154  0.200717
# MKT     0.724248 -0.032154  1.000000  0.747766
# PROFIT  0.972900  0.200717  0.747766  1.000000

# %% [markdown]
# ### RND should be the preductor for profit
# ### profit ~ RND
# ### Prfit = B0 + B1 * RND(X)

# %% [markdown]
# ## Step 3 - Seperate x(RND), Y9(PROFIT)

# %%
X = df[["RND"]]
Y = df["PROFIT"]

# %%
X.head()
# Out:
#          RND
# 0  165349.20
# 1  162597.70
# 2  153441.51
# 3  144372.41
# 4  142107.34

# %%
Y.head()
# Out:
# 0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: PROFIT, dtype: float64

# %% [markdown]
# ## Step 4 - Train the model

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(49032.89914125215)

# %%
model.coef_
# Out:
# array([0.85429137])

# %% [markdown]
# ## Profit_pred = 49032.9 + 0.8543 * RND

# %% [markdown]
# ## Step 5 - Evaluate the mode

# %%
model.score(X,Y)
# Out:
# 0.9465353160804393

# %%
ypred = model.predict(X)
ypred[0:5]
# Out:
# array([190289.29389289, 187938.71118575, 180116.65707807, 172369.00320589,
#        170433.97345032])

# %%
Y.head()
# Out:
# 0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: PROFIT, dtype: float64

# %%
from sklearn.metrics import (
    root_mean_squared_error,
    mean_absolute_error,
    mean_absolute_percentage_error,
    r2_score
)

def evalute_model(model, x,y):
    ypred = model.predict(x)
    rmse = root_mean_squared_error(y,ypred)
    mae = mean_absolute_error(y, ypred)
    mape = mean_absolute_percentage_error(y, ypred)
    r2 = r2_score(y, ypred)
    print(f"RMSE : {rmse:.2f}")
    print(f"MAE : {mae:.2f}")
    print(f"MAPE : {mape:.2F}")
    print(f"R2 : {r2: .2%}")

# %%
evalute_model(model, X, Y)
# Out:
# RMSE : 9226.10
# MAE : 6910.98
# MAPE : 0.11
# R2 :  94.65%

# %%
sns.regplot(data = df, x = "RND", y = "PROFIT", line_kws = {"color" : "red"})
# Out:
# <Axes: xlabel='RND', ylabel='PROFIT'>

# %% [markdown]
# ## Step 6 - Out of sample prediction(Inference)

# %%
rnd = 60_000
profit = model.predict([[rnd]])
print(profit)
# Out:
# [100290.38139758]
# c:\Users\Dell\Pictures\DS Document\ML\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
